# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Motor_Vehicle_Collisions_-_Crashes.csv')
df.head()
# Out:
# C:\Users\BISMA BASHIR\AppData\Local\Temp\ipykernel_13212\1543598116.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Motor_Vehicle_Collisions_-_Crashes.csv')
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987321 entries, 0 to 1987320
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
# ...

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df['CONTRIBUTING FACTOR VEHICLE 1'].unique()
# Out:
# array(['Aggressive Driving/Road Rage', 'Pavement Slippery',
#        'Following Too Closely', 'Unspecified', nan, 'Passing Too Closely',
#        'Driver Inexperience', 'Passing or Lane Usage Improper',
#        'Turning Improperly', 'Unsafe Lane Changing', 'Unsafe Speed',
#        'Reaction to Uninvolved Vehicle', 'Steering Failure',
#        'Traffic Control Disregarded', 'Other Vehicular',
#        'Driver Inattention/Distraction', 'Oversized Vehicle',
#        'Pedestrian/Bicyclist/Other Pedestrian Error/Confusion',
#        'Alcohol Involvement', 'View Obstructed/Limited',
#        'Failure to Yield Right-of-Way', 'Illnes', 'Lost Consciousness',
#        'Brakes Defective', 'Backing Unsafely', 'Glare',
#        'Passenger Distraction', 'Fell Asleep', 'Obstruction/Debris',
#        'Tinted Windows', 'Animals Action', 'Drugs (illegal)',
#        'Pavement Defective', 'Other Lighting Defects',
#        'Outside Car Distraction', 'Driverless/Runaway Vehicle',
# ...

# %%
df['VEHICLE TYPE CODE 1'].value_counts()
# Out:
# Sedan                                  536600
# Station Wagon/Sport Utility Vehicle    423029
# PASSENGER VEHICLE                      416206
# SPORT UTILITY / STATION WAGON          180291
# Taxi                                    49132
#                                         ...
# CITYWIDE                                    1
# SC                                          1
# gas mo ped                                  1
# STREET                                      1
# Military v                                  1
# Name: VEHICLE TYPE CODE 1, Length: 1509, dtype: int64

# %%
df.isnull().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           618045
# ZIP CODE                          618283
# LATITUDE                          227222
# LONGITUDE                         227222
# LOCATION                          227222
# ON STREET NAME                    416003
# CROSS STREET NAME                 739381
# OFF STREET NAME                  1663689
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       6176
# CONTRIBUTING FACTOR VEHICLE 2     301227
# CONTRIBUTING FACTOR VEHICLE 3    1847112
# CONTRIBUTING FACTOR VEHICLE 4    1955946
# CONTRIBUTING FACTOR VEHICLE 5    1978863
# ...

# %%
crash_frequency = len(df)
print("Overall Crash Frequency:", crash_frequency)
# Out:
# Overall Crash Frequency: 1987321

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df['CRASH DATE'] = pd.to_datetime(df['CRASH DATE'])
df['Year'] = df['CRASH DATE'].dt.year
df['Month'] = df['CRASH DATE'].dt.month
crash_frequency_year = df['Year'].value_counts().sort_index()
crash_frequency_month = df['Month'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
plt.plot(crash_frequency_year.index, crash_frequency_year.values, marker='o')
plt.xlabel('Year')
plt.ylabel('Crash Frequency')
plt.title('Crash Frequency by Year')
# Out:
# Text(0.5, 1.0, 'Crash Frequency by Year')

# %%
plt.figure(figsize=(10, 4))
plt.bar(crash_frequency_month.index, crash_frequency_month.values)
plt.xlabel('Month')
plt.ylabel('Crash Frequency')
plt.title('Crash Frequency by Month')
# Out:
# Text(0.5, 1.0, 'Crash Frequency by Month')

# %%
crash_frequency_borough = df['BOROUGH'].value_counts()
df['CRASH TIME'] = pd.to_datetime(df['CRASH TIME'])
df['Hour'] = df['CRASH TIME'].dt.hour
crash_frequency_time_of_day = df['Hour'].value_counts().sort_index()
df['Day of Week'] = df['CRASH DATE'].dt.dayofweek
crash_frequency_day_of_week = df['Day of Week'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
colors = ['red', 'blue', 'green', 'yellow', 'purple']
crash_frequency_borough.plot(kind='bar',color=colors)
plt.xlabel('Borough')
plt.ylabel('Crash Frequency')
plt.title('Crash Frequency by Borough')
# Out:
# Text(0.5, 1.0, 'Crash Frequency by Borough')

# %%
plt.figure(figsize=(10, 6))
crash_frequency_time_of_day.plot(kind='line', marker='o')
plt.xlabel('Hour of Day')
plt.ylabel('Crash Frequency')
plt.title('Crash Frequency by Time of Day')
plt.xticks(range(24))
plt.show()

# %%
weekday_labels = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
plt.figure(figsize=(10, 6))
crash_frequency_day_of_week.plot(kind='bar')
plt.xlabel('Day of Week')
plt.ylabel('Crash Frequency')
plt.title('Crash Frequency by Day of the Week')
plt.xticks(range(7), weekday_labels)
plt.show()

# %%
contributing_factors = pd.concat([df['CONTRIBUTING FACTOR VEHICLE 1'], df['CONTRIBUTING FACTOR VEHICLE 2']], axis=0)
contributing_factor_counts = contributing_factors.value_counts()
plt.figure(figsize=(10, 6))
top_contributing_factors = contributing_factor_counts.head(10)
colors = ['red', 'blue', 'green', 'yellow', 'purple']
top_contributing_factors.plot(kind='bar',color=colors)
plt.xlabel('Contributing Factor')
plt.ylabel('Crash Frequency')
plt.title('Top 10 Most Common Contributing Factors in Crashes')
plt.show()

# %%
print("Top 10 Most Common Contributing Factors:")
print(top_contributing_factors)
# Out:
# Top 10 Most Common Contributing Factors:
# Unspecified                       2105040
# Driver Inattention/Distraction     483714
# Failure to Yield Right-of-Way      133770
# Following Too Closely              123376
# Other Vehicular                     92779
# Backing Unsafely                    81855
# Passing or Lane Usage Improper      66250
# Fatigued/Drowsy                     58151
# Turning Improperly                  57752
# Passing Too Closely                 57171
# dtype: int64

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5',
#        'Year', 'Month', 'Hour', 'Day of Week'],
#       dtype='object')

# %%
df['NUMBER OF PERSONS INJURED'].unique()
# Out:
# array([ 2.,  1.,  0.,  4.,  3.,  5.,  7.,  6.,  9., 18.,  8., 11., 17.,
#        10., 14., 15., 12., 13., 40., 16., nan, 20., 22., 31., 19., 27.,
#        32., 24., 43., 21., 23., 34.])

# %%
numerical_columns = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numerical_columns.corr()
plt.figure(figsize=(10, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
correlation_matrix = numerical_columns.corr()
correlation_matrix
# Out:
#                                LATITUDE  LONGITUDE  NUMBER OF PERSONS INJURED  \
# LATITUDE                       1.000000  -0.962256                  -0.008515
# LONGITUDE                     -0.962256   1.000000                   0.008987
# NUMBER OF PERSONS INJURED     -0.008515   0.008987                   1.000000
# NUMBER OF PERSONS KILLED      -0.000987   0.001035                   0.015384
# NUMBER OF PEDESTRIANS INJURED -0.004121   0.004372                   0.279632
# NUMBER OF PEDESTRIANS KILLED  -0.001725   0.001704                   0.002547
# NUMBER OF CYCLIST INJURED     -0.004790   0.004099                   0.173193
# NUMBER OF CYCLIST KILLED       0.000489  -0.000493                  -0.000845
# NUMBER OF MOTORIST INJURED    -0.005287   0.005895                   0.907076
# NUMBER OF MOTORIST KILLED      0.000091   0.000015                   0.021087
# COLLISION_ID                  -0.038020   0.037552                   0.052868
# ...

# %% [markdown]
# #### see the correlation above the required features will be selected based on the higher correlation values i.e ("number of persons injured" their the correaltion is higher with "number of motorist injured and number of motorist killed"  )

# %%
dependent_variable = 'NUMBER OF PERSONS INJURED'
independent_variables = ['NUMBER OF MOTORIST KILLED', 'NUMBER OF MOTORIST INJURED','NUMBER OF PEDESTRIANS INJURED','NUMBER OF PEDESTRIANS KILLED']
data=df[[dependent_variable] + independent_variables]
data.dropna(inplace=True)
# Out:
# C:\Users\BISMA BASHIR\AppData\Local\Temp\ipykernel_13212\2700997993.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
data.head()
# Out:
#    NUMBER OF PERSONS INJURED  NUMBER OF MOTORIST KILLED  \
# 0                        2.0                          0
# 1                        1.0                          0
# 2                        0.0                          0
# 3                        0.0                          0
# 4                        0.0                          0
#
#    NUMBER OF MOTORIST INJURED  NUMBER OF PEDESTRIANS INJURED  \
# 0                           2                              0
# 1                           1                              0
# 2                           0                              0
# 3                           0                              0
# 4                           0                              0
#
#    NUMBER OF PEDESTRIANS KILLED
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0

# %%
## statistic analysis
data.describe()
# Out:
#        NUMBER OF PERSONS INJURED  NUMBER OF MOTORIST KILLED  \
# count               1.987303e+06               1.987303e+06
# mean                2.981483e-01               5.746482e-04
# std                 6.894522e-01               2.611517e-02
# min                 0.000000e+00               0.000000e+00
# 25%                 0.000000e+00               0.000000e+00
# 50%                 0.000000e+00               0.000000e+00
# 75%                 0.000000e+00               0.000000e+00
# max                 4.300000e+01               5.000000e+00
#
#        NUMBER OF MOTORIST INJURED  NUMBER OF PEDESTRIANS INJURED  \
# count                1.987303e+06                   1.987303e+06
# mean                 2.150794e-01                   5.476618e-02
# std                  6.506615e-01                   2.404188e-01
# min                  0.000000e+00                   0.000000e+00
# 25%                  0.000000e+00                   0.000000e+00
# ...

# %%
## correlation table
data.corr()
# Out:
#                                NUMBER OF PERSONS INJURED  \
# NUMBER OF PERSONS INJURED                       1.000000
# NUMBER OF MOTORIST KILLED                       0.021087
# NUMBER OF MOTORIST INJURED                      0.907076
# NUMBER OF PEDESTRIANS INJURED                   0.279632
# NUMBER OF PEDESTRIANS KILLED                    0.002547
#
#                                NUMBER OF MOTORIST KILLED  \
# NUMBER OF PERSONS INJURED                       0.021087
# NUMBER OF MOTORIST KILLED                       1.000000
# NUMBER OF MOTORIST INJURED                      0.024353
# NUMBER OF PEDESTRIANS INJURED                  -0.002849
# NUMBER OF PEDESTRIANS KILLED                    0.005752
#
#                                NUMBER OF MOTORIST INJURED  \
# NUMBER OF PERSONS INJURED                        0.907076
# NUMBER OF MOTORIST KILLED                        0.024353
# NUMBER OF MOTORIST INJURED                       1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1987303 entries, 0 to 1987320
# Data columns (total 5 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   NUMBER OF PERSONS INJURED      float64
#  1   NUMBER OF MOTORIST KILLED      int64
#  2   NUMBER OF MOTORIST INJURED     int64
#  3   NUMBER OF PEDESTRIANS INJURED  int64
#  4   NUMBER OF PEDESTRIANS KILLED   int64
# dtypes: float64(1), int64(4)
# memory usage: 91.0 MB

# %%
x=data.drop('NUMBER OF PERSONS INJURED',axis=1)
y=data['NUMBER OF PERSONS INJURED']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=60)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 0.033218070066571403

# %%
model.coef_
# Out:
# array([-0.01495095,  0.98426975,  0.97361599, -0.02303454])

# %%
Cdf=pd.DataFrame(model.coef_,index=x.columns,columns=['coef'])
Cdf
# Out:
#                                    coef
# NUMBER OF MOTORIST KILLED     -0.014951
# NUMBER OF MOTORIST INJURED     0.984270
# NUMBER OF PEDESTRIANS INJURED  0.973616
# NUMBER OF PEDESTRIANS KILLED  -0.023035

# %%
data = {
    'FEATURES': ['coefficients for 10% test-size', 'coefficients for 20% test_size', 'coefficients for 30% test_size', 'coefficients for 40% test size', 'coefficients for 50% test_size'],
    'NUMBER OF MOTORIST KILLED': [-0.015031, -0.015377, -0.014951, -0.015732, -0.016609],
    'NUMBER OF MOTORIST INJURED': [0.984334, 0.984281, 0.984270, 0.984110, 0.983977],
    'NUMBER OF PEDESTRIANS INJURED': [0.973737, 0.973703, 0.973616, 0.973538, 0.973560],
    'NUMBER OF PEDESTRIANS KILLED': [-0.023170, -0.022684, -0.023035, -0.022049, -0.022526],
    'INTERCEPT': [0.033202, 0.033239, 0.033218, 0.033247, 0.033247]
}

coefficient = pd.DataFrame(data=data)
coefficient.set_index('FEATURES', inplace=True)

def custom_format(value):
    if value is not None:
        return f'{value:.4f}'
    return ''

styled_results = coefficient.style.applymap(lambda x: 'background-color: lightyellow')
styled_results.format(custom_format)
# Out:
# <style type="text/css">
# #T_4ae3d_row0_col0, #T_4ae3d_row0_col1, #T_4ae3d_row0_col2, #T_4ae3d_row0_col3, #T_4ae3d_row0_col4, #T_4ae3d_row1_col0, #T_4ae3d_row1_col1, #T_4ae3d_row1_col2, #T_4ae3d_row1_col3, #T_4ae3d_row1_col4, #T_4ae3d_row2_col0, #T_4ae3d_row2_col1, #T_4ae3d_row2_col2, #T_4ae3d_row2_col3, #T_4ae3d_row2_col4, #T_4ae3d_row3_col0, #T_4ae3d_row3_col1, #T_4ae3d_row3_col2, #T_4ae3d_row3_col3, #T_4ae3d_row3_col4, #T_4ae3d_row4_col0, #T_4ae3d_row4_col1, #T_4ae3d_row4_col2, #T_4ae3d_row4_col3, #T_4ae3d_row4_col4 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_4ae3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ae3d_level0_col0" class="col_heading level0 col0" >NUMBER OF MOTORIST KILLED</th>
#       <th id="T_4ae3d_level0_col1" class="col_heading level0 col1" >NUMBER OF MOTORIST INJURED</th>
#       <th id="T_4ae3d_level0_col2" class="col_heading level0 col2" >NUMBER OF PEDESTRIANS INJURED</th>
# ...

# %%
prediction=model.predict(x_test)
prediction
# Out:
# array([0.03321807, 0.03321807, 0.03321807, ..., 0.03321807, 0.03321807,
#        0.03321807])

# %%
## residuals distribution plot
sns.distplot(y_test-prediction,bins=500)
# Out:
# C:\Users\BISMA BASHIR\AppData\Local\Temp\ipykernel_13212\240119836.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-prediction,bins=500)
# <Axes: xlabel='NUMBER OF PERSONS INJURED', ylabel='Density'>

# %%
# predictions scatter plot
plt.scatter(y_test,prediction)

# %%
from sklearn.metrics import explained_variance_score,mean_squared_error,mean_absolute_error,r2_score

# %%
print('accuracy score:',r2_score(y_test,prediction))
print('mean_absolute_error:',mean_absolute_error(y_test,prediction))
mse=mean_squared_error(y_test,prediction)
print('mean_squared_error:',mse)
rmse=np.sqrt(mse)
print('root_mean_squared_error:',rmse)
# Out:
# accuracy score: 0.9388117469586091
# mean_absolute_error: 0.056055124934818776
# mean_squared_error: 0.029201232283471087
# root_mean_squared_error: 0.17088368056508815

# %%
## perfomance metrics dataframe according to  the varied test_size
data = {
    'Metric': ['R-squared (R2)', 'Mean Absolute Error (MAE)', 'Mean Squared Error (MSE)', 'Root Mean Squared Error (RMSE)'],
    '10%': [0.9374175044915588, 0.05591346219621301, 0.029520610587526173, 0.1718156296369052],
    '20%': [0.9373062534701234, 0.05610638808984766, 0.02992152188650177, 0.17297838560497023],
    '30%': [0.9376380843750185, 0.056109240842344775, 0.029608033738615046, 0.1722688775218367],
    '40%': [0.938761377789274, 0.056105339501740174, 0.029208255590771774, 0.17090422929457239],
    '50%': [0.9383471210270355, 0.05616041504667672, 0.029287354591353766, 0.17113548606689896]
}
results_df = pd.DataFrame(data)
results_df.set_index('Metric', inplace=True)
def custom_format(value):
    if value is not None:
        return f'{value:.4f}'
    return ''
formatted_results = results_df.applymap(custom_format)
styled_results = formatted_results.style.applymap(lambda x: 'background-color: lightyellow')
styled_results
# Out:
# <style type="text/css">
# #T_0cd5c_row0_col0, #T_0cd5c_row0_col1, #T_0cd5c_row0_col2, #T_0cd5c_row0_col3, #T_0cd5c_row0_col4, #T_0cd5c_row1_col0, #T_0cd5c_row1_col1, #T_0cd5c_row1_col2, #T_0cd5c_row1_col3, #T_0cd5c_row1_col4, #T_0cd5c_row2_col0, #T_0cd5c_row2_col1, #T_0cd5c_row2_col2, #T_0cd5c_row2_col3, #T_0cd5c_row2_col4, #T_0cd5c_row3_col0, #T_0cd5c_row3_col1, #T_0cd5c_row3_col2, #T_0cd5c_row3_col3, #T_0cd5c_row3_col4 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_0cd5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cd5c_level0_col0" class="col_heading level0 col0" >10%</th>
#       <th id="T_0cd5c_level0_col1" class="col_heading level0 col1" >20%</th>
#       <th id="T_0cd5c_level0_col2" class="col_heading level0 col2" >30%</th>
#       <th id="T_0cd5c_level0_col3" class="col_heading level0 col3" >40%</th>
#       <th id="T_0cd5c_level0_col4" class="col_heading level0 col4" >50%</th>
#     </tr>
#     <tr>
# ...
